# %%
# %pip list
# Out:
# Package                      Version
# ---------------------------- -----------
# accelerate                   1.1.1
# aiofiles                     23.2.1
# aiohappyeyeballs             2.6.1
# aiohttp                      3.11.18
# aiosignal                    1.3.2
# altair                       5.5.0
# annotated-types              0.7.0
# anyio                        4.9.0
# asttokens                    3.0.0
# attrs                        25.3.0
# bcrypt                       5.0.0
# beautifulsoup4               4.13.4
# blinker                      1.7.0
# Brotli                       1.1.0
# bs4                          0.0.2
# cachetools                   5.5.2
# certifi                      2025.1.31
# cffi                         2.0.0
# charset-normalizer           3.4.1
# click                        8.1.7
# colorama                     0.4.6
# comm                         0.2.3
# contourpy                    1.3.3
# cryptography                 46.0.1
# customtkinter                5.2.2
# cycler                       0.12.1
# darkdetect                   0.8.0
# dataclasses-json             0.6.7
# debugpy                      1.8.17
# decorator                    5.2.1
# distro                       1.9.0
# docx2txt                     0.9
# dotenv                       0.9.9
# ecdsa                        0.19.1
# executing                    2.2.1
# fastapi                      0.117.1
# ffmpy                        0.6.4
# filelock                     3.20.0
# filetype                     1.2.0
# Flask                        3.0.2
# Flask-SQLAlchemy             3.1.1
# fonttools                    4.59.2
# frozenlist                   1.6.0
# fsspec                       2025.10.0
# gitdb                        4.0.12
# GitPython                    3.1.44
# google-ai-generativelanguage 0.9.0
# google-api-core              2.25.1
# google-api-python-client     2.182.0
# google-auth                  2.40.3
# google-auth-httplib2         0.2.0
# google-generativeai          0.8.5
# googleapis-common-protos     1.70.0
# gradio                       4.44.0
# gradio_client                1.3.0
# greenlet                     3.0.3
# groovy                       0.1.2
# grpcio                       1.75.0
# grpcio-status                1.71.2
# h11                          0.14.0
# hf-xet                       1.2.0
# httpcore                     1.0.8
# httplib2                     0.31.0
# httpx                        0.28.1
# httpx-sse                    0.4.0
# huggingface-hub              0.36.0
# idna                         3.10
# importlib_resources          6.5.2
# ipykernel                    6.30.1
# ipython                      9.6.0
# ipython_pygments_lexers      1.1.1
# itsdangerous                 2.1.2
# jedi                         0.19.2
# Jinja2                       3.1.3
# jiter                        0.11.1
# joblib                       1.5.2
# jsonpatch                    1.33
# jsonpointer                  3.0.0
# jsonschema                   4.23.0
# jsonschema-specifications    2025.4.1
# jupyter_client               8.6.3
# jupyter_core                 5.8.1
# kagglehub                    0.3.13
# kiwisolver                   1.4.9
# langchain                    1.0.3
# langchain-classic            1.0.0
# langchain-community          0.4.1
# langchain-core               1.0.2
# langchain-google-genai       3.0.0
# langchain-huggingface        0.1.0
# langchain-ollama             1.0.0
# langchain-text-splitters     1.0.0
# langgraph                    1.0.2
# langgraph-checkpoint         3.0.0
# langgraph-prebuilt           1.0.2
# langgraph-sdk                0.2.9
# langsmith                    0.4.39
# logging                      0.4.9.6
# markdown-it-py               4.0.0
# MarkupSafe                   2.1.5
# marshmallow                  3.26.1
# matplotlib                   3.10.5
# matplotlib-inline            0.1.7
# mdurl                        0.1.2
# mpmath                       1.3.0
# multidict                    6.4.3
# mypy_extensions              1.1.0
# mysql-connector-python       8.3.0
# narwhals                     1.36.0
# nest-asyncio                 1.6.0
# networkx                     3.5
# nltk                         3.9.2
# numpy                        2.2.5
# ollama                       0.6.0
# openai                       0.28.0
# orjson                       3.10.16
# ormsgpack                    1.11.0
# packaging                    24.0
# pandas                       2.2.3
# parso                        0.8.5
# passlib                      1.7.4
# pillow                       10.4.0
# pip                          25.3
# platformdirs                 4.4.0
# plumbum                      1.8.2
# prompt_toolkit               3.0.52
# propcache                    0.3.1
# proto-plus                   1.26.1
# protobuf                     5.29.4
# psutil                       7.1.0
# pure_eval                    0.2.3
# pyarrow                      19.0.1
# pyasn1                       0.6.1
# pyasn1_modules               0.4.2
# pycparser                    2.23
# pydantic                     2.11.3
# pydantic_core                2.33.1
# pydantic-settings            2.11.0
# pydeck                       0.9.1
# pydub                        0.25.1
# Pygments                     2.19.2
# pyparsing                    3.2.3
# PyPDF2                       3.0.1
# python-dateutil              2.9.0.post0
# python-dotenv                1.1.0
# python-jose                  3.5.0
# python-multipart             0.0.12
# pytz                         2025.2
# pywin32                      306
# PyYAML                       6.0.2
# pyzmq                        27.1.0
# referencing                  0.36.2
# regex                        2025.10.23
# requests                     2.32.5
# requests-toolbelt            1.0.0
# rich                         14.2.0
# rpds-py                      0.24.0
# rsa                          4.9.1
# ruff                         0.14.3
# safehttpx                    0.1.7
# safetensors                  0.6.2
# scikit-learn                 1.7.1
# scipy                        1.16.1
# seaborn                      0.13.2
# semantic-version             2.10.0
# sentence-transformers        5.1.2
# setuptools                   80.9.0
# shellingham                  1.5.4
# six                          1.17.0
# smmap                        5.0.2
# sniffio                      1.3.1
# soupsieve                    2.7
# SQLAlchemy                   2.0.29
# stack-data                   0.6.3
# starlette                    0.48.0
# streamlit                    1.44.1
# sympy                        1.13.1
# tenacity                     8.5.0
# threadpoolctl                3.6.0
# tokenizers                   0.20.3
# toml                         0.10.2
# tomlkit                      0.12.0
# torch                        2.4.1
# tornado                      6.4.2
# tqdm                         4.67.1
# traitlets                    5.14.3
# transformers                 4.46.3
# typer                        0.20.0
# typer-slim                   0.20.0
# typing_extensions            4.13.2
# typing-inspect               0.9.0
# typing-inspection            0.4.0
# tzdata                       2025.2
# uritemplate                  4.2.0
# urllib3                      2.4.0
# uvicorn                      0.37.0
# watchdog                     6.0.0
# wcwidth                      0.2.14
# websockets                   12.0
# Werkzeug                     3.0.1
# wheel                        0.45.1
# winapps                      0.2.0
# xxhash                       3.6.0
# yarl                         1.20.0
# zstandard                    0.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# imports
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import classification_report, accuracy_score
from pickle import dump

# %%
#load the data
data=pd.read_csv("diabetes_july25.csv")
data
# Out:
#     Age  Gender   BMI  Fasting_Sugar  HbA1c Hypertension Family_History  \
# 0    45    Male  28.5          120.0    6.2          Yes            Yes
# 1    32  Female  22.1           95.0    5.4           No             No
# 2    50  Female  31.0          140.0    7.1          Yes            Yes
# 3    28    Male  24.8           89.0    5.1           No             No
# 4    55    Male  29.7            NaN    6.8          Yes            Yes
# ..  ...     ...   ...            ...    ...          ...            ...
# 85   34  Female  25.8          100.0    5.4           No             No
# 86   52    Male  31.7          140.0    7.1          Yes            Yes
# 87   28  Female  23.6           90.0    5.1           No             No
# 88   44    Male  28.3          122.0    6.3          Yes             No
# 89   55  Female  31.3          138.0    7.0          Yes            Yes
#
#    Diabetes
# 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4       Yes
# ..      ...
# 85       No
# 86      Yes
# 87       No
# 88      Yes
# 89      Yes
#
# [90 rows x 8 columns]

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#     Age  Gender   BMI  Fasting_Sugar  HbA1c Hypertension Family_History  \
# 0    45    Male  28.5          120.0    6.2          Yes            Yes
# 1    32  Female  22.1           95.0    5.4           No             No
# 2    50  Female  31.0          140.0    7.1          Yes            Yes
# 3    28    Male  24.8           89.0    5.1           No             No
# 5    36  Female  26.5          110.0    5.9           No            Yes
# ..  ...     ...   ...            ...    ...          ...            ...
# 85   34  Female  25.8          100.0    5.4           No             No
# 86   52    Male  31.7          140.0    7.1          Yes            Yes
# 87   28  Female  23.6           90.0    5.1           No             No
# 88   44    Male  28.3          122.0    6.3          Yes             No
# 89   55  Female  31.3          138.0    7.0          Yes            Yes
#
#    Diabetes
# 0       Yes
# 1        No
# 2       Yes
# 3        No
# 5        No
# ..      ...
# 85       No
# 86      Yes
# 87       No
# 88      Yes
# 89      Yes
#
# [85 rows x 8 columns]

# %%
data.isna().sum()
# Out:
# Age               0
# Gender            0
# BMI               0
# Fasting_Sugar     0
# HbA1c             0
# Hypertension      0
# Family_History    0
# Diabetes          0
# dtype: int64

# %%
#faetures and target
features=data.drop(["Diabetes"],axis="columns")
target=data["Diabetes"]

# %%
features
# Out:
#     Age  Gender   BMI  Fasting_Sugar  HbA1c Hypertension Family_History
# 0    45    Male  28.5          120.0    6.2          Yes            Yes
# 1    32  Female  22.1           95.0    5.4           No             No
# 2    50  Female  31.0          140.0    7.1          Yes            Yes
# 3    28    Male  24.8           89.0    5.1           No             No
# 5    36  Female  26.5          110.0    5.9           No            Yes
# ..  ...     ...   ...            ...    ...          ...            ...
# 85   34  Female  25.8          100.0    5.4           No             No
# 86   52    Male  31.7          140.0    7.1          Yes            Yes
# 87   28  Female  23.6           90.0    5.1           No             No
# 88   44    Male  28.3          122.0    6.3          Yes             No
# 89   55  Female  31.3          138.0    7.0          Yes            Yes
#
# [85 rows x 7 columns]

# %%
target
# Out:
# 0     Yes
# 1      No
# 2     Yes
# 3      No
# 5      No
#      ...
# 85     No
# 86    Yes
# 87     No
# 88    Yes
# 89    Yes
# Name: Diabetes, Length: 85, dtype: object

# %%
#handle cat data
nfeatures=pd.get_dummies(features)
nfeatures
# Out:
#     Age   BMI  Fasting_Sugar  HbA1c  Gender_Female  Gender_Male  \
# 0    45  28.5          120.0    6.2          False         True
# 1    32  22.1           95.0    5.4           True        False
# 2    50  31.0          140.0    7.1           True        False
# 3    28  24.8           89.0    5.1          False         True
# 5    36  26.5          110.0    5.9           True        False
# ..  ...   ...            ...    ...            ...          ...
# 85   34  25.8          100.0    5.4           True        False
# 86   52  31.7          140.0    7.1          False         True
# 87   28  23.6           90.0    5.1           True        False
# 88   44  28.3          122.0    6.3          False         True
# 89   55  31.3          138.0    7.0           True        False
#
#     Hypertension_No  Hypertension_Yes  Family_History_No  Family_History_Yes
# 0             False              True              False                True
# 1              True             False               True               False
# 2             False              True              False                True
# 3              True             False               True               False
# 5              True             False              False                True
# ..              ...               ...                ...                 ...
# 85             True             False               True               False
# 86            False              True              False                True
# 87             True             False               True               False
# 88            False              True               True               False
# 89            False              True              False                True
#
# [85 rows x 10 columns]

# %%
nfeatures.values
# Out:
# array([[45, 28.5, 120.0, 6.2, False, True, False, True, False, True],
#        [32, 22.1, 95.0, 5.4, True, False, True, False, True, False],
#        [50, 31.0, 140.0, 7.1, True, False, False, True, False, True],
#        [28, 24.8, 89.0, 5.1, False, True, True, False, True, False],
#        [36, 26.5, 110.0, 5.9, True, False, True, False, False, True],
#        [42, 27.3, 115.0, 6.3, False, True, False, True, True, False],
#        [60, 33.2, 150.0, 7.5, True, False, False, True, False, True],
#        [25, 23.0, 85.0, 4.9, False, True, True, False, True, False],
#        [48, 30.1, 130.0, 6.5, True, False, False, True, False, True],
#        [29, 21.9, 92.0, 5.0, False, True, True, False, True, False],
#        [51, 32.4, 145.0, 7.0, True, False, False, True, False, True],
#        [34, 25.6, 98.0, 5.3, False, True, True, False, True, False],
#        [47, 28.9, 125.0, 6.4, True, False, False, True, True, False],
#        [38, 26.7, 105.0, 5.7, False, True, True, False, False, True],
#        [56, 31.5, 135.0, 6.9, True, False, False, True, False, True],
#        [43, 27.8, 118.0, 6.1, True, False, True, False, False, True],
#        [52, 30.8, 142.0, 7.2, False, True, False, True, False, True],
#        [31, 23.7, 93.0, 5.2, True, False, True, False, True, False],
#        [44, 28.2, 122.0, 6.3, False, True, False, True, True, False],
#        [59, 34.0, 155.0, 7.8, True, False, False, True, False, True],
#        [26, 23.2, 86.0, 4.9, False, True, True, False, True, False],
#        [49, 29.5, 128.0, 6.6, True, False, False, True, False, True],
#        [33, 25.1, 96.0, 5.2, False, True, True, False, True, False],
#        [46, 29.0, 127.0, 6.5, True, False, False, True, True, False],
#        [37, 26.2, 103.0, 5.6, False, True, True, False, False, True],
#        [54, 31.8, 138.0, 7.1, True, False, False, True, False, True],
#        [30, 24.0, 90.0, 5.1, False, True, True, False, True, False],
#        [41, 27.0, 113.0, 6.0, True, False, True, False, False, True],
#        [53, 32.1, 143.0, 7.3, False, True, False, True, False, True],
#        [35, 25.9, 100.0, 5.4, True, False, True, False, True, False],
#        [58, 33.5, 148.0, 7.6, True, False, False, True, False, True],
#        [24, 22.0, 84.0, 4.8, False, True, True, False, True, False],
#        [39, 27.5, 112.0, 5.8, True, False, True, False, False, True],
#        [57, 32.7, 147.0, 7.4, False, True, False, True, False, True],
#        [40, 26.8, 108.0, 5.7, True, False, True, False, True, False],
#        [62, 35.2, 160.0, 8.0, True, False, False, True, False, True],
#        [50, 30.5, 132.0, 6.7, True, False, False, True, False, True],
#        [36, 25.3, 97.0, 5.3, False, True, True, False, True, False],
#        [45, 28.7, 123.0, 6.4, True, False, False, True, True, False],
#        [29, 23.5, 91.0, 5.1, True, False, True, False, True, False],
#        [48, 30.0, 129.0, 6.6, False, True, False, True, False, True],
#        [34, 25.5, 99.0, 5.4, True, False, True, False, True, False],
#        [52, 31.2, 137.0, 6.9, True, False, False, True, False, True],
#        [27, 22.8, 88.0, 5.0, False, True, True, False, True, False],
#        [44, 28.0, 121.0, 6.2, True, False, False, True, True, False],
#        [55, 31.6, 139.0, 7.0, False, True, False, True, False, True],
#        [31, 24.2, 94.0, 5.2, True, False, True, False, True, False],
#        [42, 27.6, 117.0, 6.1, False, True, False, True, True, False],
#        [60, 33.8, 152.0, 7.7, True, False, False, True, False, True],
#        [25, 22.3, 85.0, 4.9, False, True, True, False, True, False],
#        [47, 29.2, 126.0, 6.5, True, False, False, True, False, True],
#        [33, 25.0, 95.0, 5.2, False, True, True, False, True, False],
#        [56, 31.9, 136.0, 7.0, True, False, False, True, False, True],
#        [28, 23.8, 89.0, 5.1, False, True, True, False, True, False],
#        [49, 29.8, 131.0, 6.7, True, False, False, True, False, True],
#        [37, 26.4, 104.0, 5.6, False, True, True, False, False, True],
#        [61, 34.5, 158.0, 7.9, True, False, False, True, False, True],
#        [26, 23.0, 85.0, 4.9, True, False, True, False, True, False],
#        [43, 27.9, 119.0, 6.2, False, True, False, True, True, False],
#        [51, 32.3, 144.0, 7.1, True, False, False, True, False, True],
#        [32, 24.5, 93.0, 5.1, False, True, True, False, True, False],
#        [46, 28.8, 124.0, 6.4, True, False, False, True, True, False],
#        [38, 26.6, 106.0, 5.7, False, True, True, False, False, True],
#        [30, 24.1, 91.0, 5.1, True, False, True, False, True, False],
#        [45, 28.4, 120.0, 6.3, False, True, False, True, False, True],
#        [35, 25.7, 101.0, 5.5, True, False, True, False, True, False],
#        [53, 32.5, 145.0, 7.3, False, True, False, True, False, True],
#        [39, 27.2, 111.0, 5.9, True, False, True, False, False, True],
#        [59, 33.7, 151.0, 7.7, True, False, False, True, False, True],
#        [41, 27.1, 114.0, 6.0, False, True, True, False, True, False],
#        [54, 31.4, 137.0, 6.9, True, False, False, True, False, True],
#        [29, 23.3, 88.0, 5.0, False, True, True, False, True, False],
#        [47, 29.1, 125.0, 6.5, True, False, False, True, True, False],
#        [36, 25.4, 98.0, 5.3, False, True, True, False, True, False],
#        [50, 30.3, 133.0, 6.7, True, False, False, True, False, True],
#        [31, 24.3, 94.0, 5.2, True, False, True, False, True, False],
#        [42, 27.7, 118.0, 6.2, True, False, False, True, True, False],
#        [58, 33.3, 149.0, 7.6, False, True, False, True, False, True],
#        [25, 22.7, 86.0, 4.9, True, False, True, False, True, False],
#        [48, 30.2, 130.0, 6.6, False, True, False, True, False, True],
#        [34, 25.8, 100.0, 5.4, True, False, True, False, True, False],
#        [52, 31.7, 140.0, 7.1, False, True, False, True, False, True],
#        [28, 23.6, 90.0, 5.1, True, False, True, False, True, False],
#        [44, 28.3, 122.0, 6.3, False, True, False, True, True, False],
#        [55, 31.3, 138.0, 7.0, True, False, False, True, False, True]],
#       dtype=object)

# %%
x_train,x_test,y_train,y_test=train_test_split(nfeatures.values,target)

# %%
x_train
# Out:
# array([[51, 32.4, 145.0, 7.0, True, False, False, True, False, True],
#        [46, 28.8, 124.0, 6.4, True, False, False, True, True, False],
#        [28, 23.8, 89.0, 5.1, False, True, True, False, True, False],
#        [29, 21.9, 92.0, 5.0, False, True, True, False, True, False],
#        [48, 30.0, 129.0, 6.6, False, True, False, True, False, True],
#        [31, 23.7, 93.0, 5.2, True, False, True, False, True, False],
#        [47, 28.9, 125.0, 6.4, True, False, False, True, True, False],
#        [47, 29.2, 126.0, 6.5, True, False, False, True, False, True],
#        [36, 25.4, 98.0, 5.3, False, True, True, False, True, False],
#        [32, 22.1, 95.0, 5.4, True, False, True, False, True, False],
#        [42, 27.7, 118.0, 6.2, True, False, False, True, True, False],
#        [45, 28.7, 123.0, 6.4, True, False, False, True, True, False],
#        [38, 26.6, 106.0, 5.7, False, True, True, False, False, True],
#        [41, 27.1, 114.0, 6.0, False, True, True, False, True, False],
#        [36, 26.5, 110.0, 5.9, True, False, True, False, False, True],
#        [34, 25.5, 99.0, 5.4, True, False, True, False, True, False],
#        [33, 25.0, 95.0, 5.2, False, True, True, False, True, False],
#        [56, 31.5, 135.0, 6.9, True, False, False, True, False, True],
#        [37, 26.2, 103.0, 5.6, False, True, True, False, False, True],
#        [41, 27.0, 113.0, 6.0, True, False, True, False, False, True],
#        [43, 27.8, 118.0, 6.1, True, False, True, False, False, True],
#        [32, 24.5, 93.0, 5.1, False, True, True, False, True, False],
#        [47, 29.1, 125.0, 6.5, True, False, False, True, True, False],
#        [24, 22.0, 84.0, 4.8, False, True, True, False, True, False],
#        [52, 31.2, 137.0, 6.9, True, False, False, True, False, True],
#        [30, 24.1, 91.0, 5.1, True, False, True, False, True, False],
#        [42, 27.6, 117.0, 6.1, False, True, False, True, True, False],
#        [45, 28.5, 120.0, 6.2, False, True, False, True, False, True],
#        [51, 32.3, 144.0, 7.1, True, False, False, True, False, True],
#        [57, 32.7, 147.0, 7.4, False, True, False, True, False, True],
#        [52, 30.8, 142.0, 7.2, False, True, False, True, False, True],
#        [49, 29.5, 128.0, 6.6, True, False, False, True, False, True],
#        [60, 33.8, 152.0, 7.7, True, False, False, True, False, True],
#        [44, 28.0, 121.0, 6.2, True, False, False, True, True, False],
#        [29, 23.5, 91.0, 5.1, True, False, True, False, True, False],
#        [45, 28.4, 120.0, 6.3, False, True, False, True, False, True],
#        [25, 22.7, 86.0, 4.9, True, False, True, False, True, False],
#        [49, 29.8, 131.0, 6.7, True, False, False, True, False, True],
#        [61, 34.5, 158.0, 7.9, True, False, False, True, False, True],
#        [62, 35.2, 160.0, 8.0, True, False, False, True, False, True],
#        [27, 22.8, 88.0, 5.0, False, True, True, False, True, False],
#        [40, 26.8, 108.0, 5.7, True, False, True, False, True, False],
#        [50, 31.0, 140.0, 7.1, True, False, False, True, False, True],
#        [44, 28.2, 122.0, 6.3, False, True, False, True, True, False],
#        [39, 27.5, 112.0, 5.8, True, False, True, False, False, True],
#        [30, 24.0, 90.0, 5.1, False, True, True, False, True, False],
#        [26, 23.2, 86.0, 4.9, False, True, True, False, True, False],
#        [55, 31.3, 138.0, 7.0, True, False, False, True, False, True],
#        [25, 22.3, 85.0, 4.9, False, True, True, False, True, False],
#        [29, 23.3, 88.0, 5.0, False, True, True, False, True, False],
#        [26, 23.0, 85.0, 4.9, True, False, True, False, True, False],
#        [33, 25.1, 96.0, 5.2, False, True, True, False, True, False],
#        [54, 31.8, 138.0, 7.1, True, False, False, True, False, True],
#        [50, 30.3, 133.0, 6.7, True, False, False, True, False, True],
#        [28, 24.8, 89.0, 5.1, False, True, True, False, True, False],
#        [35, 25.9, 100.0, 5.4, True, False, True, False, True, False],
#        [31, 24.3, 94.0, 5.2, True, False, True, False, True, False],
#        [35, 25.7, 101.0, 5.5, True, False, True, False, True, False],
#        [39, 27.2, 111.0, 5.9, True, False, True, False, False, True],
#        [37, 26.4, 104.0, 5.6, False, True, True, False, False, True],
#        [25, 23.0, 85.0, 4.9, False, True, True, False, True, False],
#        [59, 33.7, 151.0, 7.7, True, False, False, True, False, True],
#        [54, 31.4, 137.0, 6.9, True, False, False, True, False, True]],
#       dtype=object)

# %%
x_test
# Out:
# array([[60, 33.2, 150.0, 7.5, True, False, False, True, False, True],
#        [38, 26.7, 105.0, 5.7, False, True, True, False, False, True],
#        [28, 23.6, 90.0, 5.1, True, False, True, False, True, False],
#        [53, 32.1, 143.0, 7.3, False, True, False, True, False, True],
#        [56, 31.9, 136.0, 7.0, True, False, False, True, False, True],
#        [44, 28.3, 122.0, 6.3, False, True, False, True, True, False],
#        [58, 33.5, 148.0, 7.6, True, False, False, True, False, True],
#        [53, 32.5, 145.0, 7.3, False, True, False, True, False, True],
#        [52, 31.7, 140.0, 7.1, False, True, False, True, False, True],
#        [42, 27.3, 115.0, 6.3, False, True, False, True, True, False],
#        [48, 30.1, 130.0, 6.5, True, False, False, True, False, True],
#        [43, 27.9, 119.0, 6.2, False, True, False, True, True, False],
#        [34, 25.6, 98.0, 5.3, False, True, True, False, True, False],
#        [31, 24.2, 94.0, 5.2, True, False, True, False, True, False],
#        [34, 25.8, 100.0, 5.4, True, False, True, False, True, False],
#        [58, 33.3, 149.0, 7.6, False, True, False, True, False, True],
#        [50, 30.5, 132.0, 6.7, True, False, False, True, False, True],
#        [46, 29.0, 127.0, 6.5, True, False, False, True, True, False],
#        [48, 30.2, 130.0, 6.6, False, True, False, True, False, True],
#        [59, 34.0, 155.0, 7.8, True, False, False, True, False, True],
#        [36, 25.3, 97.0, 5.3, False, True, True, False, True, False],
#        [55, 31.6, 139.0, 7.0, False, True, False, True, False, True]],
#       dtype=object)

# %%
model=LogisticRegression(max_iter=1000)
model.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
cr=classification_report(y_test,model.predict(x_test))

# %%
cr
# Out:
# '              precision    recall  f1-score   support\n\n          No       1.00      1.00      1.00         6\n         Yes       1.00      1.00      1.00        16\n\n    accuracy                           1.00        22\n   macro avg       1.00      1.00      1.00        22\nweighted avg       1.00      1.00      1.00        22\n'

# %%
x_test
# Out:
# array([[60, 33.2, 150.0, 7.5, True, False, False, True, False, True],
#        [38, 26.7, 105.0, 5.7, False, True, True, False, False, True],
#        [28, 23.6, 90.0, 5.1, True, False, True, False, True, False],
#        [53, 32.1, 143.0, 7.3, False, True, False, True, False, True],
#        [56, 31.9, 136.0, 7.0, True, False, False, True, False, True],
#        [44, 28.3, 122.0, 6.3, False, True, False, True, True, False],
#        [58, 33.5, 148.0, 7.6, True, False, False, True, False, True],
#        [53, 32.5, 145.0, 7.3, False, True, False, True, False, True],
#        [52, 31.7, 140.0, 7.1, False, True, False, True, False, True],
#        [42, 27.3, 115.0, 6.3, False, True, False, True, True, False],
#        [48, 30.1, 130.0, 6.5, True, False, False, True, False, True],
#        [43, 27.9, 119.0, 6.2, False, True, False, True, True, False],
#        [34, 25.6, 98.0, 5.3, False, True, True, False, True, False],
#        [31, 24.2, 94.0, 5.2, True, False, True, False, True, False],
#        [34, 25.8, 100.0, 5.4, True, False, True, False, True, False],
#        [58, 33.3, 149.0, 7.6, False, True, False, True, False, True],
#        [50, 30.5, 132.0, 6.7, True, False, False, True, False, True],
#        [46, 29.0, 127.0, 6.5, True, False, False, True, True, False],
#        [48, 30.2, 130.0, 6.6, False, True, False, True, False, True],
#        [59, 34.0, 155.0, 7.8, True, False, False, True, False, True],
#        [36, 25.3, 97.0, 5.3, False, True, True, False, True, False],
#        [55, 31.6, 139.0, 7.0, False, True, False, True, False, True]],
#       dtype=object)

# %%
prediction = model.predict(x_test)

# %%
prediction
# Out:
# array(['Yes', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'No', 'Yes'], dtype=object)

# %%
import joblib

joblib.dump(filename="model3.pkl",value = model)
# Out:
# ['model3.pkl']
